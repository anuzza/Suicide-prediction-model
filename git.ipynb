# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd Suicide Prevention
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/Suicide Prevention

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Suicide Prevention/.git/

# %%
# !git remote set-url origin https://github.com/anuzza/Sucide-prediction-model.git

# %%
# !git config --global user.email 'anuja3580@gmail.com'
# !git config --global user.name 'anuzza'

# %%
# !git add .
# !git commit -m 'added colab project'
# !git branch -m main
# Out:
# [main d24da98] added colab project
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push https://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@github.com/anuzza/Sucide-prediction-model.git
# Out:
# Counting objects: 25, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (25/25), done.
# Writing objects: 100% (25/25), 1.28 MiB | 5.39 MiB/s, done.
# Total 25 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), done.
# To https://github.com/anuzza/Sucide-prediction-model.git
#  * [new branch]      main -> main

# %%
# !git --version
# Out:
# git version 2.17.1
