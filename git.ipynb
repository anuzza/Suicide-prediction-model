# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd Suicide Prevention
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/Suicide Prevention

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Suicide Prevention/.git/

# %%
# !git remote add origin https://anuzza:Githubanuja44@github.com/anuzza/Sucide-prediction-model.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://github.com/anuzza/Sucide-prediction-model.git (fetch)
# origin	https://github.com/anuzza/Sucide-prediction-model.git (push)

# %%
# !git remote set-url origin https://anuzza:Githubanuja44@github.com/anuzza/Sucide-prediction-model.git

# %%
# !git config --global user.email 'anuja3580@gmail.com'
# !git config --global user.name 'anuzza'

# %%
# !git add .
# !git commit -m 'added colab project'
# !git branch -m main
# Out:
# [main 32a8f79] added colab project
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push --set-upstream origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
